# %% [markdown]
# # TAMER Project - Kaggle Setup
#
# Notebook này cài đặt và chạy TAMER Project trên Kaggle với Python 3.7 và conda

# %%
# Cài đặt Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /kaggle/working/miniconda
# !rm Miniconda3-latest-Linux-x86_64.sh

# Thêm conda vào PATH
import os
os.environ['PATH'] = "/kaggle/working/miniconda/bin:" + os.environ['PATH']
# Out:
# --2025-11-14 07:57:19--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157891003 (151M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 150.58M   178MB/s    in 0.8s
#
# 2025-11-14 07:57:20 (178 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [157891003/157891003]
#
# PREFIX=/kaggle/working/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /kaggle/working/miniconda

# %%
# Tạo môi trường Python 3.7
# !/kaggle/working/miniconda/bin/conda create -n tamer python=3.7 -y
# Out:
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     - https://repo.anaconda.com/pkgs/main
#     - https://repo.anaconda.com/pkgs/r
#
# To accept these channels' Terms of Service, run the following commands:
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# For information on safely removing channels from your conda configuration,
# please see the official documentation:
#
#     https://www.anaconda.com/docs/tools/working-with-conda/channels

# %%
# Kiểm tra phiên bản Python và pip
shell_script = """
source /kaggle/working/miniconda/bin/activate tamer
python --version
pip --version
"""
with open("activate_env.sh", "w") as f:
    f.write(shell_script)
# !bash activate_env.sh
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.
#
#
# Python 3.13.9
# pip 25.2 from /kaggle/working/miniconda/lib/python3.13/site-packages/pip (python 3.13)

# %%
# Clone repo
# !git clone https://github.com/KhaiHASO/TAMER-Project.git
# Out:
# Cloning into 'TAMER-Project'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 768 (delta 81), reused 81 (delta 44), pack-reused 637 (from 1)
# Receiving objects: 100% (768/768), 266.80 MiB | 43.13 MiB/s, done.
# Resolving deltas: 100% (475/475), done.
# Updating files: 100% (264/264), done.

# %%
# Di chuyển vào thư mục dự án
# %cd TAMER-Project/0-baseline
# Out:
# /kaggle/working/TAMER-Project/0-baseline

# %%
# Cài đặt các gói từ conda
# !source /kaggle/working/miniconda/bin/activate tamer && conda install pytorch-lightning=1.4.9 torchmetrics=0.6.0 -c conda-forge -y
# !source /kaggle/working/miniconda/bin/activate tamer && conda install pandoc=1.19.2.1 -c conda-forge -y
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.
#
#
#
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.

# %%
# Cài đặt libstdcxx-ng để fix lỗi GLIBCXX
# !source /kaggle/working/miniconda/bin/activate tamer && conda install -c conda-forge libstdcxx-ng -y
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.

# %%
# Cài đặt các gói từ requirements.txt và setup.py
# !source /kaggle/working/miniconda/bin/activate tamer && pip install -r requirements.txt && pip install -e .
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.

# %% [markdown]
# ## Chuẩn bị dữ liệu
#
# Có hai cách để lấy dữ liệu:
# 1. Giải nén từ repo (nếu có sẵn)
# 2. Tải từ Kaggle dataset (nếu đã upload)

# %%
# Cách 1: Giải nén từ repo
# !unzip /kaggle/working/TAMER-Project/0-baseline/data/CROHME.zip -d /kaggle/working/TAMER-Project/0-baseline/data/
# Out:
# Archive:  /kaggle/working/TAMER-Project/0-baseline/data/CROHME.zip
#    creating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/
#    creating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/train/
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/train/caption.txt
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/train/images.pkl
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/dictionary.txt
#    creating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2014/
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2014/caption.txt
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2014/images.pkl
#    creating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2019/
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2019/caption.txt
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2019/images.pkl
#    creating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2016/
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2016/caption.txt
#   inflating: /kaggle/working/TAMER-Project/0-baseline/data/crohme/2016/images.pkl

# %%
# Cách 2: Sử dụng từ Kaggle dataset (bỏ comment nếu sử dụng cách này)
# !cp /kaggle/input/crohme-dataset/CROHME.zip /kaggle/working/TAMER-Project/0-baseline/data/
# !unzip /kaggle/working/TAMER-Project/0-baseline/data/CROHME.zip -d /kaggle/working/TAMER-Project/0-baseline/data/

# %% [markdown]
# ## Chạy training

# %%
# Chạy training với cấu hình CROHME
# !source /kaggle/working/miniconda/bin/activate tamer && python train.py --config config/crohme.yaml --trainer.gpus=2
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.

# %%
# !source /kaggle/working/miniconda/bin/activate tamer && python train.py --config config/crohme.yaml --trainer.resume_from_checkpoint=/kaggle/working/TAMER-Project/0-baseline/lightning_logs/version_0/checkpoints/epoch59-step45059-val_ExpRate0.4717.ckpt --trainer.gpus=2
# Out:
# EnvironmentNameNotFound: Could not find conda environment: tamer
# You can list all discoverable environments with `conda info --envs`.

# %%
# !mkdir -p /kaggle/working/TAMER-Project/0-baseline/lightning_logs/version_0/checkpoints
# !cp /kaggle/input/checkpoint/epoch59-step45059-val_ExpRate0.4717.ckpt /kaggle/working/TAMER-Project/0-baseline/lightning_logs/version_0/checkpoints/

# %%
# !ls
# Out:
# best_metrics_debug.csv	setup.py
# config			tamer
# data			tamer37_baseline.ipynb
# eval			tamer37_baseline.ipynbZone.Identifier
# images			TAMER_Kaggle_Setup.ipynb
# lightning_logs		TAMER_Kaggle_Setup.ipynbZone.Identifier
# README.md		train.py
# requirements.txt

# %% [markdown]
# ## Lưu kết quả và môi trường
#
# Lưu checkpoints và logs để có thể sử dụng trong các phiên tiếp theo

# %%
# Lưu kết quả training
# !mkdir -p /kaggle/output/tamer_results
# !cp -r /kaggle/working/TAMER-Project/0-baseline/lightning_logs /kaggle/output/tamer_results/

# %%
# Nén thư mục tamer_results thành file tar.gz
# !tar -czvf tamer_results.tar.gz /kaggle/output/tamer_results
# Out:
# tar: Removing leading `/' from member names
# /kaggle/output/tamer_results/
# /kaggle/output/tamer_results/lightning_logs/
# /kaggle/output/tamer_results/lightning_logs/version_0/
# /kaggle/output/tamer_results/lightning_logs/version_0/checkpoints/
# /kaggle/output/tamer_results/lightning_logs/version_0/checkpoints/epoch59-step45059-val_ExpRate0.4717.ckpt

# %%
# Chép file nén vào thư mục working
# !cp tamer_results.tar.gz /kaggle/working/

# %%
# Xác nhận file đã được chép thành công
# !ls -lh /kaggle/working/tamer_results.tar.gz
# Out:
# -rw-r--r-- 1 root root 88M Nov 14 07:58 /kaggle/working/tamer_results.tar.gz
